# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/CSE-Data-Mining-Warehouse-Lab-426/Week 09 Outlier Analysis/network_data.csv')
data
# Out:
#         Source_IP Destination_IP  Packet_Count  Session_Duration  \
# 0    192.168.1.39       10.0.0.5   1017.317957         66.459178
# 1    192.168.1.29       10.0.0.4    968.864553         73.743095
# 2    192.168.1.15       10.0.0.1   1233.556412         54.015064
# 3    192.168.1.43       10.0.0.5   1050.884169         42.590181
# 4     192.168.1.8       10.0.0.2   1067.520532         52.908736
# ..            ...            ...           ...               ...
# 495   192.168.1.5       10.0.0.3   1176.731987         75.579688
# 496  192.168.1.12       10.0.0.1   1130.464576         58.138777
# 497  192.168.1.16       10.0.0.2    684.721569         52.313137
# 498  192.168.1.26       10.0.0.4   1295.308070         58.253621
# 499  192.168.1.26       10.0.0.3  12000.000000        900.000000
#
#        Bytes_Sent  Destination_Port
# 0    2.500291e+05                21
# 1    1.664690e+05              8080
# 2    2.696233e+05                21
# 3    1.874977e+05                22
# 4    2.144347e+05                80
# ..            ...               ...
# 495  1.803994e+05                22
# 496  2.529968e+05                80
# 497  2.308503e+05                22
# 498  2.341785e+05             12345
# 499  8.000000e+06              8080
#
# [500 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(data['Packet_Count'], data['Bytes_Sent'])
plt.xlabel('Packet Count')
plt.ylabel('Bytes Sent')
plt.title('Scatter Plot of Packet Count vs. Bytes Sent')
plt.grid(True)
plt.show()

# %%
numerical_features = ['Packet_Count', 'Session_Duration', 'Bytes_Sent']

# %%
for feature in numerical_features:
    data[f'{feature}_ZScore'] = np.abs((data[feature] - data[feature].mean()) / data[feature].std())

data
# Out:
#         Source_IP Destination_IP  Packet_Count  Session_Duration  \
# 0    192.168.1.39       10.0.0.5   1017.317957         66.459178
# 1    192.168.1.29       10.0.0.4    968.864553         73.743095
# 2    192.168.1.15       10.0.0.1   1233.556412         54.015064
# 3    192.168.1.43       10.0.0.5   1050.884169         42.590181
# 4     192.168.1.8       10.0.0.2   1067.520532         52.908736
# ..            ...            ...           ...               ...
# 495   192.168.1.5       10.0.0.3   1176.731987         75.579688
# 496  192.168.1.12       10.0.0.1   1130.464576         58.138777
# 497  192.168.1.16       10.0.0.2    684.721569         52.313137
# 498  192.168.1.26       10.0.0.4   1295.308070         58.253621
# 499  192.168.1.26       10.0.0.3  12000.000000        900.000000
#
#        Bytes_Sent  Destination_Port  Packet_Count_ZScore  \
# 0    2.500291e+05                21             0.139424
# 1    1.664690e+05              8080             0.168179
# 2    2.696233e+05                21             0.011098
# 3    1.874977e+05                22             0.119504
# 4    2.144347e+05                80             0.109632
# ..            ...               ...                  ...
# 495  1.803994e+05                22             0.044820
# 496  2.529968e+05                80             0.072277
# 497  2.308503e+05                22             0.336804
# 498  2.341785e+05             12345             0.025549
# 499  8.000000e+06              8080             6.378247
#
#      Session_Duration_ZScore  Bytes_Sent_ZScore
# 0                   0.082357           0.093653
# 1                   0.021282           0.168318
# 2                   0.186698           0.076145
# 3                   0.282494           0.149528
# 4                   0.195975           0.125459
# ..                       ...                ...
# 495                 0.005883           0.155871
# 496                 0.152122           0.091002
# 497                 0.200969           0.110790
# 498                 0.151159           0.107817
# 499                 6.906736           6.831313
#
# [500 rows x 9 columns]

# %%
for feature in numerical_features:
  data[f'{feature}_Outlier_Z'] = (data[f'{feature}_ZScore'].abs() > 3)
data
# Out:
#         Source_IP Destination_IP  Packet_Count  Session_Duration  \
# 0    192.168.1.39       10.0.0.5   1017.317957         66.459178
# 1    192.168.1.29       10.0.0.4    968.864553         73.743095
# 2    192.168.1.15       10.0.0.1   1233.556412         54.015064
# 3    192.168.1.43       10.0.0.5   1050.884169         42.590181
# 4     192.168.1.8       10.0.0.2   1067.520532         52.908736
# ..            ...            ...           ...               ...
# 495   192.168.1.5       10.0.0.3   1176.731987         75.579688
# 496  192.168.1.12       10.0.0.1   1130.464576         58.138777
# 497  192.168.1.16       10.0.0.2    684.721569         52.313137
# 498  192.168.1.26       10.0.0.4   1295.308070         58.253621
# 499  192.168.1.26       10.0.0.3  12000.000000        900.000000
#
#        Bytes_Sent  Destination_Port  Packet_Count_ZScore  \
# 0    2.500291e+05                21             0.139424
# 1    1.664690e+05              8080             0.168179
# 2    2.696233e+05                21             0.011098
# 3    1.874977e+05                22             0.119504
# 4    2.144347e+05                80             0.109632
# ..            ...               ...                  ...
# 495  1.803994e+05                22             0.044820
# 496  2.529968e+05                80             0.072277
# 497  2.308503e+05                22             0.336804
# 498  2.341785e+05             12345             0.025549
# 499  8.000000e+06              8080             6.378247
#
#      Session_Duration_ZScore  Bytes_Sent_ZScore  Packet_Count_Outlier_Z  \
# 0                   0.082357           0.093653                   False
# 1                   0.021282           0.168318                   False
# 2                   0.186698           0.076145                   False
# 3                   0.282494           0.149528                   False
# 4                   0.195975           0.125459                   False
# ..                       ...                ...                     ...
# 495                 0.005883           0.155871                   False
# 496                 0.152122           0.091002                   False
# 497                 0.200969           0.110790                   False
# 498                 0.151159           0.107817                   False
# 499                 6.906736           6.831313                    True
#
#      Session_Duration_Outlier_Z  Bytes_Sent_Outlier_Z
# 0                         False                 False
# 1                         False                 False
# 2                         False                 False
# 3                         False                 False
# 4                         False                 False
# ..                          ...                   ...
# 495                       False                 False
# 496                       False                 False
# 497                       False                 False
# 498                       False                 False
# 499                        True                  True
#
# [500 rows x 12 columns]

# %%
outlier_data = data[
    (data['Packet_Count_Outlier_Z']) &
    (data['Session_Duration_Outlier_Z']) &
    (data['Bytes_Sent_Outlier_Z'])
]

outlier_data
# Out:
#         Source_IP Destination_IP  Packet_Count  Session_Duration  Bytes_Sent  \
# 28   192.168.1.25       10.0.0.1       10000.0             600.0  10000000.0
# 33   192.168.1.16       10.0.0.4       15000.0             900.0   8000000.0
# 82   192.168.1.23       10.0.0.5       12000.0            1200.0  10000000.0
# 181  192.168.1.28       10.0.0.2       10000.0            1200.0   5000000.0
# 247  192.168.1.29       10.0.0.3       12000.0             600.0   5000000.0
# 343  192.168.1.21       10.0.0.3       15000.0             600.0  10000000.0
# 362  192.168.1.35       10.0.0.2       15000.0             900.0  10000000.0
# 462  192.168.1.26       10.0.0.1       15000.0             600.0   5000000.0
# 466   192.168.1.1       10.0.0.5       12000.0            1200.0   8000000.0
# 499  192.168.1.26       10.0.0.3       12000.0             900.0   8000000.0
#
#      Destination_Port  Packet_Count_ZScore  Session_Duration_ZScore  \
# 28              12345             5.191347                 4.391289
# 33                 22             8.158597                 6.906736
# 82                 21             6.378247                 9.422183
# 181             12345             5.191347                 9.422183
# 247                22             6.378247                 4.391289
# 343               443             8.158597                 4.391289
# 362               443             8.158597                 6.906736
# 462                22             8.158597                 4.391289
# 466                21             6.378247                 9.422183
# 499              8080             6.378247                 6.906736
#
#      Bytes_Sent_ZScore  Packet_Count_Outlier_Z  Session_Duration_Outlier_Z  \
# 28            8.618408                    True                        True
# 33            6.831313                    True                        True
# 82            8.618408                    True                        True
# 181           4.150671                    True                        True
# 247           4.150671                    True                        True
# 343           8.618408                    True                        True
# 362           8.618408                    True                        True
# 462           4.150671                    True                        True
# 466           6.831313                    True                        True
# 499           6.831313                    True                        True
#
#      Bytes_Sent_Outlier_Z
# 28                   True
# 33                   True
# 82                   True
# 181                  True
# 247                  True
# 343                  True
# 362                  True
# 462                  True
# 466                  True
# 499                  True

# %%
for feature in numerical_features:
  Q1 = data['Packet_Count'].quantile(0.25)
  Q3 = data['Packet_Count'].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  data[f'{feature}_Outlier_IQR'] = (data[feature] < lower_bound) | (data[feature] > upper_bound)

data
# Out:
#         Source_IP Destination_IP  Packet_Count  Session_Duration  \
# 0    192.168.1.39       10.0.0.5   1017.317957         66.459178
# 1    192.168.1.29       10.0.0.4    968.864553         73.743095
# 2    192.168.1.15       10.0.0.1   1233.556412         54.015064
# 3    192.168.1.43       10.0.0.5   1050.884169         42.590181
# 4     192.168.1.8       10.0.0.2   1067.520532         52.908736
# ..            ...            ...           ...               ...
# 495   192.168.1.5       10.0.0.3   1176.731987         75.579688
# 496  192.168.1.12       10.0.0.1   1130.464576         58.138777
# 497  192.168.1.16       10.0.0.2    684.721569         52.313137
# 498  192.168.1.26       10.0.0.4   1295.308070         58.253621
# 499  192.168.1.26       10.0.0.3  12000.000000        900.000000
#
#        Bytes_Sent  Destination_Port  Packet_Count_ZScore  \
# 0    2.500291e+05                21             0.139424
# 1    1.664690e+05              8080             0.168179
# 2    2.696233e+05                21             0.011098
# 3    1.874977e+05                22             0.119504
# 4    2.144347e+05                80             0.109632
# ..            ...               ...                  ...
# 495  1.803994e+05                22             0.044820
# 496  2.529968e+05                80             0.072277
# 497  2.308503e+05                22             0.336804
# 498  2.341785e+05             12345             0.025549
# 499  8.000000e+06              8080             6.378247
#
#      Session_Duration_ZScore  Bytes_Sent_ZScore  Packet_Count_Outlier_Z  \
# 0                   0.082357           0.093653                   False
# 1                   0.021282           0.168318                   False
# 2                   0.186698           0.076145                   False
# 3                   0.282494           0.149528                   False
# 4                   0.195975           0.125459                   False
# ..                       ...                ...                     ...
# 495                 0.005883           0.155871                   False
# 496                 0.152122           0.091002                   False
# 497                 0.200969           0.110790                   False
# 498                 0.151159           0.107817                   False
# 499                 6.906736           6.831313                    True
#
#      Session_Duration_Outlier_Z  Bytes_Sent_Outlier_Z  \
# 0                         False                 False
# 1                         False                 False
# 2                         False                 False
# 3                         False                 False
# 4                         False                 False
# ..                          ...                   ...
# 495                       False                 False
# 496                       False                 False
# 497                       False                 False
# 498                       False                 False
# 499                        True                  True
#
#      Packet_Count_Outlier_IQR  Session_Duration_Outlier_IQR  \
# 0                       False                          True
# 1                       False                          True
# 2                       False                          True
# 3                       False                          True
# 4                       False                          True
# ..                        ...                           ...
# 495                     False                          True
# 496                     False                          True
# 497                     False                          True
# 498                     False                          True
# 499                      True                         False
#
#      Bytes_Sent_Outlier_IQR
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# ..                      ...
# 495                    True
# 496                    True
# 497                    True
# 498                    True
# 499                    True
#
# [500 rows x 15 columns]

# %%
outlier_data_IQR = data[
    (data['Packet_Count_Outlier_IQR']) &
    (data['Session_Duration_Outlier_IQR']) &
    (data['Bytes_Sent_Outlier_IQR'])
]

outlier_data_IQR
# Out:
#         Source_IP Destination_IP  Packet_Count  Session_Duration  \
# 96   192.168.1.45       10.0.0.5    460.622671         62.299544
# 118   192.168.1.9       10.0.0.2    469.806038         51.715372
#
#         Bytes_Sent  Destination_Port  Packet_Count_ZScore  \
# 96   111348.376590             12345             0.469795
# 118  232795.038826               443             0.464345
#
#      Session_Duration_ZScore  Bytes_Sent_ZScore  Packet_Count_Outlier_Z  \
# 96                  0.117234           0.217571                   False
# 118                 0.205981           0.109053                   False
#
#      Session_Duration_Outlier_Z  Bytes_Sent_Outlier_Z  \
# 96                        False                 False
# 118                       False                 False
#
#      Packet_Count_Outlier_IQR  Session_Duration_Outlier_IQR  \
# 96                       True                          True
# 118                      True                          True
#
#      Bytes_Sent_Outlier_IQR
# 96                     True
# 118                    True

# %%
outlier_data = data[
    (data['Packet_Count_Outlier_Z']) &
    (data['Session_Duration_Outlier_Z']) &
    (data['Bytes_Sent_Outlier_Z']) &
    (data['Packet_Count_Outlier_IQR']) &
    (data['Session_Duration_Outlier_IQR']) &
    (data['Bytes_Sent_Outlier_IQR'])
]

outlier_data
# Out:
# Empty DataFrame
# Columns: [Source_IP, Destination_IP, Packet_Count, Session_Duration, Bytes_Sent, Destination_Port, Packet_Count_ZScore, Session_Duration_ZScore, Bytes_Sent_ZScore, Packet_Count_Outlier_Z, Session_Duration_Outlier_Z, Bytes_Sent_Outlier_Z, Packet_Count_Outlier_IQR, Session_Duration_Outlier_IQR, Bytes_Sent_Outlier_IQR]
# Index: []

# %% [markdown]
# **Task**

# %% [markdown]
# Calculate IQR for each feature separately and then find the outliers
